# %% [markdown]
# # Recurrent Neural Network Simplified (Google Stock Price Forecasting)
#
# ### **Goals of the project -**
# * To understand the basic implemetation of the RNN and LSTM
# * To build the RNN layer by layer and understanding the significance of LSTM and the arguments used
# * Understanding the importance of Normalization in RNN
# * To understand the concept of time steps
# * Creating training and testing set from the same data by using the concept of time steps
# * Comparing the forecast of the actual and predicted stock prices
# * Understanding the significance of RNN in terms of forecasting and its limitations
# * Evaluating the RNN by RMSE value taken as a percentage of the orignal value

# %% [markdown]
# ## **Step 1** : Pre-processing

# %%
import numpy as np
import pandas as pd
import warnings  
warnings.filterwarnings('ignore') # to ignore the warnings

# %%
training = pd.read_csv("../input/google-stock-price/Google_Stock_Price_Train.csv")
training.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %% [markdown]
# **Things to consider -**
# * For this project sake we will be considering only the "Open" value of the stock as we are building the RNN
# * This is done because in RNN, one value at a time `t` is given as an input in a module and that in return gives the next predicted value at time `t+1`

# %%
real_stock_price_train = training.iloc[:, 1:2].values     # creates a 2D array having observation and feature

# %% [markdown]
# **Step - 1.1 :** Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
training2 = sc.fit_transform(real_stock_price_train)

# %% [markdown]
# **Note -**
# * We prefer `Normalization` over `Standardization` here coz the sigmoid function takes values betn 0 and 1,
# * Hence it would be better to scale our values betn 0 and 1, thus its better to do use `MinMaxScaler`

# %% [markdown]
# **Step - 1.2 :** Checking the shape

# %%
training2.shape
# Out:
# (1258, 1)

# %% [markdown]
# **Step 1.3 :** Getting the input and output values
#
# **Note -**
# * The input values must be the stock prices at time `t` and the output values should be the stock prices at time `t+1`

# %%
# hence in the input we take
X_train = training2[0:1257]  # all but last observation as we don't have the output value for it
y_train = training2[1:1258]  # values shifted by 1

# %% [markdown]
# **Step 1.4 :** Reshaping
# * We need to convert this 2D (observation and feature)array into a 3D array because it is a time series problem
# * So we need to add a *time step* of 1 because our input is stock price at time `t` and output is stock price at time `t+1` and `(t+1) - t = 1`, hence `1` is the time step

# %%
X_train = np.reshape(X_train, (1257, 1, 1))
# (1257, 1, 1) the 2nd argument is no. of features and 3rd argument is the time step

# %% [markdown]
# ## **Step - 2 :** Building the RNN

# %%
# importing libraries
from keras.models import Sequential  # initialize NN as a sequnce of layers
from keras.layers import Dense  # to add fully connected layers
from keras.layers import LSTM

# %% [markdown]
# **Step 2.1 :** Initializing the RNN

# %%
rnn_regressor = Sequential()

# %% [markdown]
# **Step 2.2 :** Adding input layer and LSTM layer
# * In the add method, we use the class corresponding to the layer we want to add
# * In this case we are adding the LSTM layer thus replacing the input layer (Dense class) by the LSTM class

# %%
rnn_regressor.add(LSTM(units=4, activation='sigmoid', input_shape=(1, 1)))

# %% [markdown]
# **Arguments used -**
# * `units` = no. of memory units
# * `input_shape=(1, 1)` means the 1st element is the time step and the 2nd element is no. of features

# %% [markdown]
# **Step 2.3 :** Adding the output layer

# %%
rnn_regressor.add(Dense(units=1))

# %% [markdown]
# **Arguments used -**
# * `units` = no. of neurons in output layer, here it is a regressor hence 1

# %% [markdown]
# **Step 2.4 :** Compiling the RNN

# %%
rnn_regressor.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# **Step 2.5 :** Fitting the RNN to training set

# %%
rnn_regressor.fit(X_train, y_train, batch_size=32, epochs=200)
# Out:
# Epoch 1/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2331
# Epoch 2/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1716
# Epoch 3/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1333
# Epoch 4/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1110
# Epoch 5/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0993
# Epoch 6/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0936
# Epoch 7/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0906
# Epoch 8/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0888
# Epoch 9/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0874
# Epoch 10/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0861
# Epoch 11/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0848
# Epoch 12/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0836
# Epoch 13/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0822
# Epoch 14/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0809
# Epoch 15/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0795
# Epoch 16/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0782
# Epoch 17/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0769
# Epoch 18/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0755
# Epoch 19/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0741
# Epoch 20/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0727
# Epoch 21/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0713
# Epoch 22/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0699
# Epoch 23/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0684
# Epoch 24/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0670
# Epoch 25/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0654
# Epoch 26/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0639
# Epoch 27/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0623
# Epoch 28/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0607
# Epoch 29/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0591
# Epoch 30/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0574
# Epoch 31/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0557
# Epoch 32/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0539
# Epoch 33/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0521
# Epoch 34/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0503
# Epoch 35/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0484
# Epoch 36/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0465
# Epoch 37/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0445
# Epoch 38/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0426
# Epoch 39/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0406
# Epoch 40/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0386
# Epoch 41/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0365
# Epoch 42/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0345
# Epoch 43/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0324
# Epoch 44/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0303
# Epoch 45/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0283
# Epoch 46/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0263
# Epoch 47/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0243
# Epoch 48/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0223
# Epoch 49/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0204
# Epoch 50/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0186
# Epoch 51/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0168
# Epoch 52/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0151
# Epoch 53/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 54/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0120
# Epoch 55/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0106
# Epoch 56/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0093
# Epoch 57/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 58/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 59/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 60/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 61/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 62/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 63/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 64/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 65/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 66/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 67/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 68/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 69/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 70/200
# 40/40 [==============================] - 0s 2ms/step - loss: 9.2274e-04
# Epoch 71/200
# 40/40 [==============================] - 0s 2ms/step - loss: 7.8254e-04
# Epoch 72/200
# 40/40 [==============================] - 0s 2ms/step - loss: 6.7602e-04
# Epoch 73/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5.9028e-04
# Epoch 74/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5.2500e-04
# Epoch 75/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.7098e-04
# Epoch 76/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.3172e-04
# Epoch 77/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.0151e-04
# Epoch 78/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7833e-04
# Epoch 79/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.6112e-04
# Epoch 80/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.4685e-04
# Epoch 81/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.3749e-04
# Epoch 82/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.2968e-04
# Epoch 83/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.2523e-04
# Epoch 84/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.2133e-04
# Epoch 85/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.1725e-04
# Epoch 86/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.1551e-04
# Epoch 87/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.1385e-04
# Epoch 88/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.1226e-04
# Epoch 89/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.1035e-04
# Epoch 90/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.1000e-04
# Epoch 91/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0831e-04
# Epoch 92/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0876e-04
# Epoch 93/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0671e-04
# Epoch 94/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0609e-04
# Epoch 95/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0543e-04
# Epoch 96/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0444e-04
# Epoch 97/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0508e-04
# Epoch 98/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0331e-04
# Epoch 99/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0245e-04
# Epoch 100/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0168e-04
# Epoch 101/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0094e-04
# Epoch 102/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0097e-04
# Epoch 103/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9913e-04
# Epoch 104/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9987e-04
# Epoch 105/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9940e-04
# Epoch 106/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9786e-04
# Epoch 107/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9824e-04
# Epoch 108/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9635e-04
# Epoch 109/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9594e-04
# Epoch 110/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9426e-04
# Epoch 111/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9574e-04
# Epoch 112/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9374e-04
# Epoch 113/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9133e-04
# Epoch 114/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9244e-04
# Epoch 115/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9280e-04
# Epoch 116/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9175e-04
# Epoch 117/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8935e-04
# Epoch 118/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8790e-04
# Epoch 119/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8773e-04
# Epoch 120/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8662e-04
# Epoch 121/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8743e-04
# Epoch 122/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8568e-04
# Epoch 123/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8455e-04
# Epoch 124/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8437e-04
# Epoch 125/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8421e-04
# Epoch 126/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8410e-04
# Epoch 127/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8277e-04
# Epoch 128/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8242e-04
# Epoch 129/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8154e-04
# Epoch 130/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8066e-04
# Epoch 131/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7961e-04
# Epoch 132/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8146e-04
# Epoch 133/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7790e-04
# Epoch 134/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7820e-04
# Epoch 135/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8008e-04
# Epoch 136/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8146e-04
# Epoch 137/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7770e-04
# Epoch 138/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7569e-04
# Epoch 139/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7490e-04
# Epoch 140/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7593e-04
# Epoch 141/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7474e-04
# Epoch 142/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7347e-04
# Epoch 143/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7317e-04
# Epoch 144/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7456e-04
# Epoch 145/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7259e-04
# Epoch 146/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7114e-04
# Epoch 147/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7117e-04
# Epoch 148/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7034e-04
# Epoch 149/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7110e-04
# Epoch 150/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6952e-04
# Epoch 151/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7001e-04
# Epoch 152/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6807e-04
# Epoch 153/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6678e-04
# Epoch 154/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6812e-04
# Epoch 155/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6788e-04
# Epoch 156/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6764e-04
# Epoch 157/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6612e-04
# Epoch 158/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6850e-04
# Epoch 159/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6619e-04
# Epoch 160/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6481e-04
# Epoch 161/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6551e-04
# Epoch 162/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6549e-04
# Epoch 163/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6342e-04
# Epoch 164/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6442e-04
# Epoch 165/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6512e-04
# Epoch 166/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6342e-04
# Epoch 167/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6329e-04
# Epoch 168/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6724e-04
# Epoch 169/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6539e-04
# Epoch 170/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6118e-04
# Epoch 171/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6042e-04
# Epoch 172/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6581e-04
# Epoch 173/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6080e-04
# Epoch 174/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6229e-04
# Epoch 175/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6297e-04
# Epoch 176/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5897e-04
# Epoch 177/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5952e-04
# Epoch 178/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5998e-04
# Epoch 179/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6338e-04
# Epoch 180/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6160e-04
# Epoch 181/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6126e-04
# Epoch 182/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6189e-04
# Epoch 183/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6260e-04
# Epoch 184/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5947e-04
# Epoch 185/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6145e-04
# Epoch 186/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5993e-04
# Epoch 187/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6020e-04
# Epoch 188/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5903e-04
# Epoch 189/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6042e-04
# Epoch 190/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6061e-04
# Epoch 191/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6111e-04
# Epoch 192/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6009e-04
# Epoch 193/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5922e-04
# Epoch 194/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5990e-04
# Epoch 195/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6443e-04
# Epoch 196/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5788e-04
# Epoch 197/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5724e-04
# Epoch 198/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5843e-04
# Epoch 199/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5779e-04
# Epoch 200/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5876e-04

# %% [markdown]
# **Step 2.6 :** Predicting and Visualizing the training results

# %%
# predicting the training results
predicted_stock_price_train = rnn_regressor.predict(X_train)
predicted_stock_price_train = sc.inverse_transform(predicted_stock_price_train)

# %%
# visualizing the training results
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.plot(real_stock_price_train, color = 'red', label='Real Google Stock Price')
plt.plot(predicted_stock_price_train, color = 'blue', label='Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# ## **Step - 3 :** Making predictions and visualizing results for testing set

# %%
testing = pd.read_csv("../input/google-stock-price/Google_Stock_Price_Test.csv")
testing.head()
# Out:
#        Date    Open    High     Low   Close     Volume
# 0  1/3/2017  778.81  789.63  775.80  786.14  1,657,300
# 1  1/4/2017  788.36  791.34  783.16  786.90  1,073,000
# 2  1/5/2017  786.08  794.48  785.02  794.02  1,335,200
# 3  1/6/2017  795.26  807.90  792.20  806.15  1,640,200
# 4  1/9/2017  806.40  809.97  802.83  806.65  1,272,400

# %% [markdown]
# **Step 3.1 :** Performing similar pre-prcoessing as performed on training set

# %%
# taking the column of "open" value of stock price
real_stock_price_test = testing.iloc[:, 1:2].values

# %%
# feature Scaling
inputs = sc.transform(real_stock_price_test)

# %% [markdown]
# **Note -** We do only ".transform" and not "fit.transform" and we use the same scaler 'sc' we used while standardzing the training data because the scaling should be done with respect to the training data and not the testing set because the minimum and maximum of the training and testing sets may vary

# %%
# reshaping
inputs = np.reshape(inputs, (20, 1, 1))     # only 20 observations in testing set

# %%
# predicting the stock price (for the year 2017)
predicted_stock_price_test = rnn_regressor.predict(inputs)     # but these are the scaled values

# %% [markdown]
# **Step 3.2 :** Performing inverse scaling

# %%
predicted_stock_price_test = sc.inverse_transform(predicted_stock_price_test)

# %%
# visualizing the results for testing
plt.figure(figsize=(20,10))
plt.plot(real_stock_price_test, color = 'red', label='Real Google Stock Price')
plt.plot(predicted_stock_price_test, color = 'blue', label='Predicted Google Stock Price')
plt.title('Google Stock Price Prediction (Test Set)')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# ## **Conclusions**
# * As there is 1 time step between the input and the output, that makes it one time step prediction
# * It is seen that the predictions are actually following the real google stock prices
# * If we imagine today is the 1st day of 2017 and we want to predict stock price for the next 60 days, we won't get these accurate results as our model was trained for 1 time step prediction
# * As amazing as that sounds it would be hard to get such close predictions because in finance, the future variations may not always be dependent on the past, hence its nearly impossible to make long term predictions of stock price

# %% [markdown]
# ## **Step - 4 :** Evaluating the RNN

# %% [markdown]
# ### **Interpretation of RMSE value :**
# * It is a way of figuring out how much a model disagrees with the actual data

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(real_stock_price_test, predicted_stock_price_test))
print('The RMSE value is', rmse)
# Out:
# The RMSE value is 7.4898687597295845

# %% [markdown]
# * We need to express this as percentage of the orignal value coz it may tell there is a prediction error of 7, but that error won't mean the same thing whether the orignal stock price was betn 1 and 10 or betn 1000 and 10000
# * Generally a good rmse expressed in terms of percentage is around or less than 1%

# %%
print('RMSE in terms of % of the orignal value is', round((rmse/real_stock_price_test.mean()*100), 2) , '%')   
# we take the avg because it would be a true representative of the real stock values
# Out:
# RMSE in terms of % of the orignal value is 0.93 %
